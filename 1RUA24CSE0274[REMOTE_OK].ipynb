# %%
import requests  
import pandas as pd  


url = "https://remoteok.com/api"
response = requests.get(url)  
data = response.json() 


jobs = data[1:] 

job_list = []
for job in jobs:
    job_list.append({
        "Company Name": job.get("company", "N/A"),
        "Job Role": job.get("position", "N/A"),
        "Location": job.get("location", "N/A"),
        "Tags": ", ".join(job.get("tags", []))
    })


df = pd.DataFrame(job_list)

df.to_csv("remoteok_jobs.csv", index=False)


df.head()
# Out:
#        Company Name                                Job Role  \
# 0   Bonfire Studios                Character Concept Artist
# 1          Coins.ph                        Strategy Manager
# 2            Aragon               Content &amp; Social Lead
# 3  The Biz Conquest                        Mobile Developer
# 4      Virta Health  Backend Software Engineer Client Group
#
#                                  Location  \
# 0                           United States
# 1  Taguig City, Metro Manila, Philippines
# 2                       Remote - Anywhere
# 3
# 4
#
#                                                 Tags
# 0                            3d, support, recruiting
# 1  manager, web3, crypto, cryptocurrencies, suppo...
# 2  web3, full-stack, technical, support, software...
# 3             dev, engineer, mobiledev, react native
# 4  software, frontend, security, training, full-s...
